# %% [markdown]
# # Лабораторная работа 2: решающее дерево на данных Titanic

# %% [markdown]
# ## 1. Загрузите выборку из файла `titanic.csv` с помощью пакета Pandas.

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder

# %%
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 2. Оставьте в выборке четыре признака: класс пассажира (Pclass), цену билета (Fare), возраст пассажира (Age) и его пол (Sex).
#
# ## 3. Обратите внимание, что признак Sex имеет строковые значения.
#
# ## 4. Выделите целевую переменную — она записана в столбце Survived.
#
# ## 5. В данных есть пропущенные значения — например, для некоторых пассажиров неизвестен их возраст. Такие записи при чтении их в pandas принимают значение nan. Найдите все объекты, у которых есть пропущенные признаки, и удалите их из выборки.

# %%
data_withoutnan = data.dropna()
X = data_withoutnan[['Pclass', 'Sex', 'Age', 'Fare']]
y_target = data_withoutnan.Survived

# %% [markdown]
# Преобразование строкового признака `Sex` в числовой с помощью OneHotEncoding (drop_first).

# %%
X_train = X.copy()
X_train[['Sex']] = OneHotEncoder(drop='first', sparse_output=False, dtype=int).fit_transform(X[['Sex']])
X_train
# Out:
#      Pclass  Sex   Age     Fare
# 1         1    0  38.0  71.2833
# 3         1    0  35.0  53.1000
# 6         1    1  54.0  51.8625
# 10        3    0   4.0  16.7000
# 11        1    0  58.0  26.5500
# ..      ...  ...   ...      ...
# 871       1    0  47.0  52.5542
# 872       1    1  33.0   5.0000
# 879       1    0  56.0  83.1583
# 887       1    0  19.0  30.0000
# 889       1    1  26.0  30.0000
#
# [183 rows x 4 columns]

# %% [markdown]
# ## 6. Обучите решающее дерево с параметром random_state=241 и остальными параметрами по умолчанию.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(random_state=241)
dt_fit = dt_model.fit(X_train, y_target)

# %% [markdown]
# ## 7. Вычислите важности признаков и найдите два признака с наибольшей важностью. Их названия будут ответами для данной задачи (в качестве ответа укажите названия признаков через запятую без пробелов).

# %%
feat_import = pd.DataFrame({'feature': X_train.columns, 'feature_importances': dt_fit.feature_importances_})
feat_import = feat_import.sort_values('feature_importances', ascending=False, ignore_index=True) 
ans = feat_import.loc[:1, 'feature']

with open('1.txt', 'w') as file:
    file.write(f'{ans[0]},{ans[1]}')
