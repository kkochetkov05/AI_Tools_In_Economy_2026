# %% [markdown]
# # 01-titanic-assignment

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"D:\ML_intro\01-titanic-assignment\titanic.csv", index_col = 'PassengerId')
total = len(df)

# %% [markdown]
# # 1. Какое количество мужчин и женщин ехало на корабле?

# %% [markdown]
#  ### В качестве ответа приведите два числа через пробел

# %%
male_count = (df['Sex'] == 'male').sum()
female_count = (df['Sex'] == 'female').sum()
print(male_count, female_count)
# Out:
# 577 314

# %% [markdown]
# # 2. Какой части пассажиров удалось выжить?

# %% [markdown]
# ###  Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
survived_proportion = ((df['Survived'] == 1).sum()) / total
print(round (survived_proportion * 100, 2))
# Out:
# 38.38

# %% [markdown]
# # Какую долю пассажиры первого класса составляли среди всех пассажиров?

# %% [markdown]
# ### Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
firsrt_class_proportion = (df['Pclass'] == 1).sum()/ total
print(round(firsrt_class_proportion, 2))
# Out:
# 0.24

# %% [markdown]
# # 4. Какого возраста были пассажиры?

# %% [markdown]
# ### Посчитайте среднее и медиану возраста пассажиров. Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.

# %%
mean_age = df['Age'].mean()
median_age = df['Age'].median()
print(mean_age, median_age)
# Out:
# 29.69911764705882 28.0

# %% [markdown]
# # 5. Коррелируют ли число братьев/сестер с числом родителей/детей?

# %% [markdown]
# ### Посчитайте корреляцию Пирсона между признаками SibSp и Parch.

# %%
correlation = df['SibSp'].corr(df['Parch'])
correlation.item()
# Out:
# 0.41483769862015646

# %% [markdown]
# # 6. Какое самое популярное женское имя на корабле?

# %% [markdown]
# ### Извлеките изполного имени пассажира (колонка Name) его личное имя (FirstName). Это задание типичный пример того, с чем сталкивается специалист по анализу данных. Данные очень разнородные ишумные, но из них требуется извлечь необходимую информацию.Попробуйте вручную разобрать несколько значений столбца Name и выработать правило для извлечения имен, а также разделенияих на женские и мужские.

# %%
female_names = {}

for name in df['Name']:
    if ' Mrs.' in name:
        if '(' in name:
            first_name = name.split('(')[1].split()[0].strip('()')
            female_names[first_name] = female_names.get(first_name, 0) + 1

    elif ' Miss.' in name:
        first_name = name.split('. ')[1].split()[0].strip('()')
        female_names[first_name] = female_names.get(first_name, 0) + 1

max_value = max(female_names.values())
max_keys = [key for key, value in female_names.items() if value == max_value]

print(max_keys, max_value)
# Out:
# ['Anna'] 15

# %%
sorted_by_value = dict(sorted(female_names.items(), key=lambda x: x[1], reverse=True))

for name, count in sorted_by_value.items():
    print(name, count)
# Out:
# Anna 15
# Mary 14
# Elizabeth 11
# Margaret 10
# Alice 6
# Bertha 5
# Maria 5
# Helen 5
# Ellen 4
# Marie 4
# Augusta 4
# Emily 4
# Ada 4
# Marion 4
# Annie 4
# Catherine 4
# Florence 3
# Elisabeth 3
# Lillian 3
# Edith 3
# Katherine 3
# Madeleine 3
# Amelia 3
# Hanora 3
# Kate 3
# Ida 3
# Jane 3
# Lily 2
# Adele 2
# Johanna 2
# Dorothy 2
# Bridget 2
# Constance 2
# Mabel 2
# Susan 2
# Mathilde 2
# Rosa 2
# Marjorie 2
# Helene 2
# Agnes 2
# Clara 2
# Elsie 2
# Rosalie 2
# Jessie 2
# Marija 2
# Lucile 2
# Hedwig 2
# Ethel 2
# Charlotte 2
# Martha 2
# Amy 2
# Laina 1
# Marguerite 1
# Hulda 1
# Emelia 1
# Torborg 1
# Selma 1
# Jamila 1
# Simonne 1
# Josefine 1
# Myna 1
# Amelie 1
# Erna 1
# Brigdet 1
# Matilda 1
# Hileni 1
# Katriina 1
# Malake 1
# Ellis 1
# Grace 1
# Sultana 1
# Elin 1
# Robina 1
# Eleanor 1
# Ann 1
# Luise 1
# Carla 1
# Elise 1
# Henriette 1
# Telma 1
# Clear 1
# Eliina 1
# Albina 1
# Irene 1
# Thamine 1
# Agda 1
# Elna 1
# Helena 1
# Hanne 1
# Gladys 1
# Lutie 1
# ...
