# %% [markdown]
# # 05-statement-linear
# ## Ответ: 0.19

# %% [markdown]
# ### 1. Загрузите обучающую и тестовую выборки из файлов perceptron train.csv и perceptron-test.csv. Целевая переменная записана в первом столбце, признаки во втором и третьем

# %%
import pandas as pd
import numpy as np

df_train = pd.read_csv(r"D:\ML_intro\05-statement-linear\perceptron-train.csv", header=None)
df_test = pd.read_csv(r"D:\ML_intro\05-statement-linear\perceptron-test.csv", header=None)

X_train = df_train[[1,2]]
y_train = df_train[0]
X_test = df_test[[1,2]]
y_test = df_test[0]

# %% [markdown]
# ### 2. Обучите персептрон со стандартными параметрами и random_state=241.
# ### 3. Подсчитайте качество (долю правильно классифицированных объектов, accuracy) полученного классификатора на тестовой выборке.

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

clf = Perceptron()
clf.fit (X_train, y_train)

y_pred = clf.predict(X_test)

score = accuracy_score(y_test, y_pred)

score
# Out:
# 0.655

# %% [markdown]
# ### 4. Нормализуйте обучающую и тестовую выборку с помощью класса StandardScaler.

# %%
from sklearn . preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### 5. Обучите персептрон на новых выборках. Найдите долю правильных ответов на тестовой выборке

# %%
clf = Perceptron()
clf.fit (X_train_scaled, y_train)

y_pred = clf.predict(X_test_scaled)

score_scale = accuracy_score(y_test, y_pred)

score_scale
# Out:
# 0.845

# %% [markdown]
# ### 6. Найдите разность между качеством на тестовой выборке после нормализации и качеством до нее. Это число и будет ответом на задание.

# %%
print(round(score_scale - score, 3))
# Out:
# 0.19
