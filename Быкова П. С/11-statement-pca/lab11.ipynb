# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %% [markdown]
# 1. Загрузите данные close_prices.csv. В этом файле приведены цены
# акций 30 компаний на закрытии торгов за каждый день периода.

# %%
data = pd.read_csv('close_prices.csv', index_col=0)

# %% [markdown]
# 2. На загруженных данных обучите преобразование PCA с числом
# компоненты равным 10. Скольких компонент хватит, чтобы объяснить 90% дисперсии?

# %%
model = PCA(n_components=10)
model.fit(data)
expl_var_ratio = model.explained_variance_ratio_
cum_var = np.cumsum(expl_var_ratio)
n_components_90 = np.argmax(cum_var >= 0.9) + 1  
print(n_components_90)
# Out:
# 4

# %% [markdown]
# 3. Примените построенное преобразование к исходным данным и возьмите значения первой компоненты.

# %%
X_pca = model.transform(data)
first_component = X_pca[:, 0]

# %% [markdown]
# 4. Загрузите информацию об индексе Доу-Джонса из файла djia_prices.csv.
# Чему равна корреляция Пирсона между первой компонентой и индексом Доу-Джонса?

# %%
data_idx = pd.read_csv('djia_index.csv', index_col=0)
print(np.corrcoef(first_component.flatten(), data_idx['^DJI'])[0, 1])
# Out:
# 0.9096522193050238

# %% [markdown]
# 5. Какая компания имеет наибольший вес в первой компоненте?

# %%
weights = model.components_[0]
max_idx = np.argmax(np.abs(weights))
company_name = data.columns[max_idx]
print(company_name)
# Out:
# V
