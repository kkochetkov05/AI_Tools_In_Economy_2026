# %% [markdown]
# ### 1. Какое количество мужчин и женщин ехало на корабле?
# В качестве ответа приведите два числа через пробел.

# %%
import pandas as pd
data = pd.read_csv ('titanic.csv', index_col = 'PassengerId')
print(data['Sex'].value_counts()['male'],data['Sex'].value_counts()['female'])
# Out:
# 577 314

# %% [markdown]
# ### 2. Какой части пассажиров удалось выжить?
# Посчитайте долю выживших пассажиров.
# Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
print((data['Survived'].value_counts(normalize=True)[1]*100).round(2))
# Out:
# 38.38

# %% [markdown]
# ### 3. Какую долю пассажиры первого класса составляли среди всех пассажиров?
# Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
print((data['Pclass'].value_counts(normalize=True)[1]*100).round(2))
# Out:
# 24.24

# %% [markdown]
# ### 4. Какого возраста были пассажиры?
# Посчитайте долю выживших пассажиров.
# Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.

# %%
print(data['Age'].mean(), data['Age'].median())
# Out:
# 29.69911764705882 28.0

# %% [markdown]
# ### 5. Коррелируют ли число братьев/сестер с числом родителей/детей?
# Посчитайте корреляцию Пирсона между признаками SibSp и Parch.

# %%
print(data[['SibSp', 'Parch']].corr().iloc[0,1])
# Out:
# 0.41483769862015624

# %% [markdown]
# ### 6. Какое самое популярное женское имя на корабле?
# Извлеките из полного имени пассажира (колонка Name) его личное имя (First Name).

# %%
def extract_the_name(full_name):
    if '(' in full_name:
        return full_name.split('(')[1][:-1]
    else:
        return full_name.split('. ')[1]
print(data[data['Sex'] == 'female']['Name'].apply(extract_the_name).value_counts().index[0])
# Out:
# Mary
