# %%
import pandas as pd
import numpy as np

# %%
titanic_data = pd.read_csv('titanic.csv', index_col = 'PassengerId')

# %% [markdown]
# ## 1. Какое количество мужчин и женщин ехало на корабле?
#
# В качестве ответа приведите два числа через пробел.

# %%
ans1, ans2 = len(titanic_data.loc[titanic_data.Sex == 'male']), len(titanic_data.loc[titanic_data.Sex == 'female'])
print(ans1, ans2)
# Out:
# 577 314

# %% [markdown]
# ## 2. Какой части пассажиров удалось выжить?
#
# Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
survived_pct = round((len(titanic_data.loc[titanic_data.Survived == 1]) / len(titanic_data) * 100), 2)
print(survived_pct)
# Out:
# 38.38

# %% [markdown]
# ## 3. Какую долю пассажиры первого класса составляли среди всех пассажиров?
#
# Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
first_class_pct = round((len(titanic_data.loc[titanic_data.Pclass == 1]) / len(titanic_data) * 100), 2)
print(first_class_pct)
# Out:
# 24.24

# %% [markdown]
# ## 4. Какого возраста были пассажиры?
#
# Посчитайте среднее и медиану возраста пассажиров. Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.

# %%
age_mean = titanic_data[titanic_data.Age.notnull()].Age.mean()
age_median = titanic_data[titanic_data.Age.notnull()].Age.median()
print(age_mean, age_median)
# Out:
# 29.69911764705882 28.0

# %% [markdown]
# ## 5. Коррелируют ли число братьев/сестер с числом родителей/детей?
#
# Посчитайте корреляцию Пирсона между признаками SibSp и Parch.

# %%
corr_val = titanic_data.SibSp.corr(titanic_data.Parch)
print(corr_val)
# Out:
# 0.41483769862015557

# %% [markdown]
# ## 6. Какое самое популярное женское имя на корабле?
#
# Извлеките из полного имени пассажира (колонка Name) его личное имя (First Name). Это задание — типичный пример того, с чем сталкивается специалист по анализу данных. Данные очень разнородные и шумные, но из них требуется извлечь необходимую информацию. Попробуйте вручную разобрать несколько значений столбца Name и выработать правило для извлечения имен, а также разделения их на женские и мужские.

# %%
female_names = {}

for name in df['Name']:
    if ' Mrs.' in name and '(' in name:
        first_name = name.split('(')[1].split()[0].strip('()')
        
    elif ' Miss.' in name:
        first_name = name.split('. ')[1].split()[0].strip('()')
        
    else:
        continue
        
    first_name = first_name.strip(' ."')
    
    if first_name:
        female_names[first_name] = female_names.get(first_name, 0) + 1

sorted_names = sorted(female_names.items(), key=lambda x: x[1], reverse=True)

print(f"Ответ: {most_popular} ({max_count} раз)")

print("Полный список женских имен:")
for name, count in sorted_names:
    print(f"{name} {count}")

max_count = sorted_names[0][1]
top_candidates = [name for name, count in sorted_names if count == max_count]
most_popular = sorted(top_candidates)[0]
# Out:
# Ответ: Anna (15 раз)
# Полный список женских имен:
# Anna 15
# Mary 14
# Elizabeth 11
# Margaret 10
# Alice 6
# Bertha 5
# Maria 5
# Helen 5
# Ellen 4
# Marie 4
# Augusta 4
# Emily 4
# Ada 4
# Marion 4
# Annie 4
# Catherine 4
# Florence 3
# Elisabeth 3
# Lillian 3
# Edith 3
# Katherine 3
# Madeleine 3
# Amelia 3
# Hanora 3
# Kate 3
# Ida 3
# Jane 3
# Lily 2
# Adele 2
# Johanna 2
# Dorothy 2
# Bridget 2
# Constance 2
# Mabel 2
# Susan 2
# Mathilde 2
# Rosa 2
# Marjorie 2
# Helene 2
# Agnes 2
# Clara 2
# Elsie 2
# Rosalie 2
# Jessie 2
# Marija 2
# Lucile 2
# Hedwig 2
# Ethel 2
# Charlotte 2
# Martha 2
# Amy 2
# Laina 1
# Marguerite 1
# Hulda 1
# Emelia 1
# Torborg 1
# Selma 1
# Jamila 1
# Simonne 1
# Josefine 1
# Myna 1
# Amelie 1
# Erna 1
# Brigdet 1
# Matilda 1
# Hileni 1
# Katriina 1
# Malake 1
# Ellis 1
# Grace 1
# Sultana 1
# Elin 1
# Robina 1
# Eleanor 1
# Ann 1
# Luise 1
# Carla 1
# Elise 1
# Henriette 1
# Telma 1
# Clear 1
# Eliina 1
# Albina 1
# Irene 1
# Thamine 1
# Agda 1
# ...
