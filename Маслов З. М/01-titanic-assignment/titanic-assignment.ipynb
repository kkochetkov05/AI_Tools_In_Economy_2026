# %% [markdown]
# Загрузка данных

# %%
import pandas as pd

titanic_data = pd.read_csv('./titanic.csv', encoding='utf-8', index_col='PassengerId')

# %% [markdown]
# 1. Какое количество мужчин и женщин ехало на корабле? В качестве
# ответа приведите два числа через пробел.

# %%
total_male = titanic_data[titanic_data['Sex'] == 'male'].shape[0]
total_female = titanic_data[titanic_data['Sex'] == 'female'].shape[0]
print(total_male, total_female)
# Out:
# 577 314

# %% [markdown]
# 2. Какой части пассажиров удалось выжить? Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух
# знаков.

# %%
survived_part = titanic_data[titanic_data['Survived'] == 1].shape[0] / titanic_data.shape[0]
print(f"{survived_part * 100:.2g}")
# Out:
# 38

# %% [markdown]
# 3. Какую долю пассажиры первого класса составляли среди всех пассажиров? Ответ приведите в процентах (число в интервале от 0 до
# 100, знак процента не нужен), округлив до двух знаков.

# %%
first_class_part = titanic_data[titanic_data['Pclass'] == 1].shape[0] / titanic_data.shape[0]
print(f"{first_class_part * 100:.2g}")
# Out:
# 24

# %% [markdown]
# 4. Какого возраста были пассажиры? Посчитайте среднее и медиану возраста пассажиров. Посчитайте среднее и медиану возраста
# пассажиров. В качестве ответа приведите два числа через пробел.

# %%
age = titanic_data['Age']
print(age.mean(), age.median())
# Out:
# 29.69911764705882 28.0

# %% [markdown]
# 5. Коррелируют ли число братьев/сестер с числом родителей/детей?
# Посчитайте корреляцию Пирсона между признаками SibSp и Parch

# %%
SibSp = titanic_data['SibSp']
Parch = titanic_data['Parch']
print(f"{SibSp.cov(Parch)/(SibSp.std() * Parch.std()):.2g}")
# Out:
# 0.41

# %% [markdown]
# 6. Какое самое популярное женское имя на корабле? Извлеките из
# полного имени пассажира (колонка Name) его личное имя (First
# Name).

# %%
def extract_name(x):
    if '(' in x:
        return x.split('(')[1].split(' ')[0]
    else:
        return x.split('.')[1].split(' ')[1]

titanic_data['Name'] = titanic_data['Name'].map(lambda x: extract_name(x))

df = titanic_data[titanic_data['Sex'] == 'female'].groupby('Name', as_index=False).agg(
    name_count = ('Name', 'count')
)
print(df[df['name_count'] == df['name_count'].max()]['Name'].iloc[0])
# Out:
# Anna
