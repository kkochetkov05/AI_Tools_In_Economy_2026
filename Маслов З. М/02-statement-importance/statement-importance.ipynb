# %% [markdown]
# 1. Загрузите выборку из файла titanic.csv с помощью пакета Pandas.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier


titanic_data = pd.read_csv('./titanic.csv', encoding='utf-8', index_col='PassengerId')

# %% [markdown]
# 2. Оставьте в выборке четыре признака: класс пассажира (Pclass), цену билета (Fare), возраст пассажира (Age) и его пол (Sex).
# 3. Обратите внимание, что признак Sex имеет строковые значения.

# %%
titanic_data = titanic_data.filter(['Sex', 'Pclass', 'Fare', 'Age', 'Survived'])

# %% [markdown]
# 4. Выделите целевую переменную — она записана в столбце Survived.

# %%
X = titanic_data.filter(['Sex', 'Pclass', 'Fare', 'Age'])
Y = titanic_data.filter(['Survived'])

# %% [markdown]
# 5. В данных есть пропущенные значения — например, для некоторых
# пассажиров неизвестен их возраст. Такие записи при чтении их в
# pandas принимают значение nan. Найдите все объекты, у которых
# есть пропущенные признаки, и удалите их из выборки.

# %%
titanic_data = titanic_data.dropna(axis=0, how='any')

# %% [markdown]
# 6. Обучите решающее дерево с параметром random_state=241 и остальными параметрами по умолчанию.

# %%
tr = DecisionTreeClassifier(random_state=241)
tr.fit(X, Y)

# %% [markdown]
# 7. Вычислите важности признаков и найдите два признака с наибольшей важностью. Их названия будут ответами для данной задачи
# (в качестве ответа укажите названия признаков через запятую без
# пробелов).

# %%
importances = tr.feature_importances_
df = pd.DataFrame({
    'feature': tr.feature_names_in_,
    'importances': tr.feature_importances_ 
})

print(sorted(importances)[-2:])
print(df.sort_values('importances', ascending=False)[:2]['feature'])
