# %% [markdown]
# # Размер случайного леса

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, cross_val_score

# %% [markdown]
# 1. Загрузите данные из файла abalone.csv.

# %%
data = pd.read_csv('abalone.csv')

# %% [markdown]
# 2. Преобразуйте признак Sex в числовой.

# %%
data['Sex'] = data['Sex'].map(lambda x: 1 if x == 'M' else (-1 if x == 'F' else 0))

# %% [markdown]
# 3. Разделите содержимое файлов на признаки и целевую переменную.

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %% [markdown]
# 4. Обучите случайный лес.

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=1)
results = []
for n_trees in range(1, 51):
    model = RandomForestRegressor(n_estimators=n_trees, random_state=1)
    scores = cross_val_score(model, X, y, cv=cv, scoring='r2')
    results.append(scores.mean())

# %%
for i, score in enumerate(results, start=1):
    if score > 0.52:
        print(i)
        break
# Out:
# 21

# %%
for i, score in enumerate(results, start=1):
    print(i, round(score, 4))
# Out:
# 1 0.1097
# 2 0.3413
# 3 0.4064
# 4 0.4448
# 5 0.465
# 6 0.4714
# 7 0.4767
# 8 0.4829
# 9 0.4894
# 10 0.4954
# 11 0.4944
# 12 0.499
# 13 0.5031
# 14 0.5073
# 15 0.5092
# 16 0.5114
# 17 0.5149
# 18 0.5172
# 19 0.5198
# 20 0.5195
# 21 0.5205
# 22 0.5208
# 23 0.5217
# 24 0.5231
# 25 0.5232
# 26 0.5243
# 27 0.5246
# 28 0.5257
# 29 0.5266
# 30 0.5271
# 31 0.5276
# 32 0.5289
# 33 0.5301
# 34 0.53
# 35 0.5298
# 36 0.5299
# 37 0.5294
# 38 0.5295
# 39 0.5295
# 40 0.5295
# 41 0.5298
# 42 0.53
# 43 0.5299
# 44 0.5297
# 45 0.5289
# 46 0.529
# 47 0.5292
# 48 0.5301
# 49 0.5308
# 50 0.531

# %% [markdown]
# Качество сначала резко растёт, а потом выходит на плато, но точно не уменьшается
