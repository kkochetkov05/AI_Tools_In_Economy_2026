# %%
import pandas as pd
import re

# %%
data = pd.read_csv('titanic.csv', index_col='PassengerId')
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# # 1. Какое количество мужчин и женщин ехало на корабле?
# В качестве ответа приведите два числа через пробел.

# %%
sex_counts = data['Sex'].value_counts()
print(sex_counts['male'], sex_counts['female'])
# Out:
# 577 314

# %% [markdown]
# # 2. Какой части пассажиров удалось выжить?
# Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух
# знаков.

# %%
survived_counts = data['Survived'].value_counts()
survived_percent = 100 * survived_counts[1] / survived_counts.sum()
print(round(survived_percent, 2))
# Out:
# 38.38

# %% [markdown]
#  # 3. Какую долю пассажиры первого класса составляли среди всех пассажиров?
#  Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
classes_counts = data['Pclass'].value_counts()
print(round(100 * classes_counts[1] / classes_counts.sum(), 2))
# Out:
# 24.24

# %% [markdown]
# # 4. Какого возраста были пассажиры?
# Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.

# %%
med_age = data['Age'].median()
mean_age = data['Age'].mean()
print(med_age, round(mean_age, 2))
# Out:
# 28.0 29.7

# %% [markdown]
# # 5. Коррелируют ли число братьев/сестер с числом родителей/детей?
# Посчитайте корреляцию Пирсона между признаками SibSp и Parch.

# %%
print(round(data['SibSp'].corr(data['Parch']), 2))
# Out:
# 0.41

# %% [markdown]
# # 6. Какое самое популярное женское имя на корабле?
# Извлеките из полного имени пассажира (колонка Name) его личное имя (FirstName).

# %%
def extract_first_name(name):
    if 'Mrs.' in name:
        match = re.search(r'\((.*?)\)', name)
        if match:
            return match.group(1).split()[0]
        else:
            return name.split('Mrs.')[1].strip().split()[0]

    elif 'Miss.' in name:
        return name.split('Miss.')[1].strip().split()[0]

    else:
        return None

data['FirstName'] = data['Name'].apply(extract_first_name)
most_common_name = data['FirstName'].value_counts().idxmax()
print(most_common_name)
# Out:
# Anna
