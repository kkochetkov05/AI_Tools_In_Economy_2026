# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# %% [markdown]
# 1. Загрузите данные close_prices.csv. В этом файле приведены цены
# акций 30 компаний на закрытии торгов за каждый день периода.

# %%
data1 = pd.read_csv('../data/close_prices.csv')
X_train = data1[data1.columns[1:]]

# %% [markdown]
# 2. На загруженных данных обучите преобразование PCA с числом
# компоненты равным 10. Скольких компонент хватит, чтобы объяснить 90% дисперсии?

# %%
pca = PCA(n_components=10)
pca.fit(X_train)
s = 0
n = 0
for i in pca.explained_variance_ratio_:
    s += i
    n += 1
    if s >= 0.9:
        break
print(n)
# Out:
# 4

# %% [markdown]
# 3. Примените построенное преобразование к исходным данным и возьмите значения первой компоненты.

# %%
comp1 = pca.transform(X_train)[:, :1]

# %% [markdown]
# 4. Загрузите информацию об индексе Доу-Джонса из файлаd jia_prices.csv.
# Чему равна корреляция Пирсона между первой компонентой и индексом Доу-Джонса?

# %%
data2 = pd.read_csv('../data/djia_index.csv')['^DJI']
answer4  = np.corrcoef(comp1.flatten(), data2)[0, 1]
print(answer4)
# Out:
# 0.9096522193050232

# %% [markdown]
# 5. Какая компания имеет наибольший вес в первой компоненте?

# %%
idx = pd.Series(pca.components_[0]).idxmax()
answer5 = data1.columns[idx + 1]
print(answer5)
# Out:
# V
